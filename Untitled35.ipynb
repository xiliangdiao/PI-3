# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
data=nc.Dataset('/ihesp/user/xiliangdiao/ihespdata/ocn300/B.E.13.B1850C5.ne120_t12.sehires38.003.sunway_02.pop.h.0261-09.TEMP.nc')

lont = data.variables['TLONG']
latt = data.variables['TLAT']
######################121-09

# %%
lont = lont[20:490:10,0:3600:10]
latt = latt[20:490:10,0:3600:10]

# %%
lont1 = np.zeros([47,361])
latt1 = np.zeros([47,361])

# %%
lont11 = lont[:,0]
latt11 = latt[:,0]

# %%
lont1[:,0:360]= lont
latt1[:,0:360]= latt
lont1[:,360]= lont11
latt1[:,360]= latt11

# %%
data0 = np.loadtxt("test190-220.out")
result0 = np.zeros([10,20])
result0 = data0

# %%
data1 = np.loadtxt("test220-250.out")
result1 = data1

# %%
result1.shape
# Out:
# (3, 20)

# %%
reu = np.vstack((data0,data1))

# %%
data2 = np.loadtxt("test250-350.out")

# %%
data3 = np.loadtxt("test350-490.out")

# %%
data4 = np.loadtxt("middle.out")

# %%
data5 = np.loadtxt("left.out")

# %%
data6 = np.loadtxt("700-900.out")

# %%
data7 = np.loadtxt("1500-2100.out")

# %%
data8 = np.loadtxt("500-700.out")

# %%
data9 = np.loadtxt("2100-2300.out")

# %%
data10 = np.loadtxt("2300-2500.out")

# %%
#data10 = np.loadtxt("0-700se.out")

# %%
data11 = np.loadtxt("1500-2100se.out")

# %%
data12 = np.loadtxt("2500-2700.out")

# %%
data13 = np.loadtxt("2700-2900.out")

# %%
data110 = np.loadtxt("2900-3100.out")
data111 = np.loadtxt("2900-3100-2.out")
data112 = np.loadtxt("2900-3100-2-1.out")
data113 = np.loadtxt("2900-3100-3.out")
data114 = np.loadtxt("2900-3100-3-1.out")
data115 = np.loadtxt("2900-3100-4.out")
data116 = np.loadtxt("2900-3100-5.out")
data117 = np.loadtxt("2900-3100-6.out")

data118 = np.loadtxt("2900-3100-7.out")
data119 = np.loadtxt("2900-3100-8.out")
data1191 = np.loadtxt("2900-3100-9.out")
data1192 = np.loadtxt("2900-3100-10.out")
data1193 = np.loadtxt("2900-3100-11.out")
data1194 = np.loadtxt("2900-3100-12.out")
data1195 = np.loadtxt("2900-3100-13.out")
data1196 = np.loadtxt("2900-3100-14-1.out")

data110[3:6,:]=data111
data110[5,:]=data112
data110[6:9,:]=data113
data110[8,:]=data114
data110[9:11,:]=data115
data110[11:13,:]=data116
data110[13:15,:]=data117
data110[15:17,:]=data118
data110[17:19,:]=data119
data110[19:21,:]=data1191
data110[21:23,:]=data1192
data110[23:25,:]=data1193
data110[25:27,:]=data1194
data110[27:29,:]=data1195
data110[29:30,:]=data1196

# %%
data210 = np.loadtxt("3100-3300.out")
data211 = np.loadtxt("3100-3300-2.out")
data212 = np.loadtxt("3100-3300-2-1.out")
#data213 = np.loadtxt("3100-3300-3.out")
#new3100-3.out
data213 = np.loadtxt("new3100-3.out")
data214 = np.loadtxt("3100-3300-4.out")
data215 = np.loadtxt("3100-3300-5.out")
data216 = np.loadtxt("3100-3300-6.out")
data217 = np.loadtxt("3100-3300-7.out")
data218 = np.loadtxt("3100-8.out")
data219 = np.loadtxt("3100-9.out")
data2110 = np.loadtxt("3100-10.out")
data2111 = np.loadtxt("3100-11.out")
data2112 = np.loadtxt("3100-12.out")
data2113 = np.loadtxt("new3100-13.out")
data2114 = np.loadtxt("3100-14.out")
data210[3:6,:]=data211
data210[5,:]=data212
data210[6:8,:]=data213
data210[8:10,:]=data214
data210[10:12,:]=data215
data210[12:14,:]=data216
data210[14:16,:]=data217
data210[16:18,:]=data218
data210[18:20,:]=data219
data210[20:22,:]=data2110
data210[22:24,:]=data2111
data210[24:26,:]=data2112
data210[26:28,:]=data2113
data210[28:30,:]=data2114

# %%
data310 = np.zeros([30,20])
data311 = np.loadtxt("3300-1.out")
data312 = np.loadtxt("3300-2.out")
data313 = np.loadtxt("3300-3.out")
data314 = np.loadtxt("3300-4.out")
data315 = np.loadtxt("3300-5.out")
data316 = np.loadtxt("3300-6.out")
data317 = np.loadtxt("3300-7.out")
data318 = np.loadtxt("3300-8.out")
data319 = np.loadtxt("3300-9.out")
data3110 = np.loadtxt("3300-10.out")
data3111 = np.loadtxt("3300-11.out")
data3112 = np.loadtxt("3300-12.out")
data3113 = np.loadtxt("3300-13.out")
data3114 = np.loadtxt("3300-14.out")
data3115 = np.loadtxt("3300-15.out")

data310[0:2,:]=data311
data310[2:4,:]=data312
data310[4:6,:]=data313
data310[6:8,:]=data314
data310[8:10,:]=data315
data310[10:12,:]=data316
data310[12:14,:]=data317
data310[14:16,:]=data318
data310[16:18,:]=data319
data310[18:20,:]=data3110
data310[20:22,:]=data3111
data310[22:24,:]=data3112
data310[24:26,:]=data3113
data310[26:28,:]=data3114
data310[28:30,:]=data3115

# %%
data410 = np.zeros([30,10])
data411 = np.loadtxt("3500-1.out")
data412 = np.loadtxt("3500-2.out")
data413 = np.loadtxt("3500-3.out")
data414 = np.loadtxt("3500-4.out")
data415 = np.loadtxt("3500-5.out")
data416 = np.loadtxt("3500-6.out")
data417 = np.loadtxt("3500-7.out")
data418 = np.loadtxt("3500-8.out")


data410[0:4,:]=data411
data410[4:8,:]=data412
data410[8:12,:]=data413
data410[12:16,:]=data414
data410[16:20,:]=data415
data410[20:24,:]=data416
data410[24:28,:]=data417
data410[28:30,:]=data418

# %%
data310.shape
# Out:
# (30, 20)

# %%
data7[24:,:] = data11

# %%
reu = np.vstack((reu,data2))

# %%
reu = np.vstack((reu,data3))

# %%
reu = np.hstack((data4,reu))

# %%
reu = np.hstack((data5,reu))

# %%
reu = np.hstack((data6,reu))

# %%
reu = np.hstack((reu,data7))

# %%
reu = np.hstack((data8,reu))

# %%
reu = np.hstack((reu,data9))

# %%
reu = np.hstack((reu,data10))

# %%
reu = np.hstack((reu,data12))

# %%
reu = np.hstack((reu,data13))

# %%
reu = np.hstack((reu,data110))

# %%
reu = np.hstack((reu,data210))

# %%
reu = np.hstack((reu,data310))

# %%
reu = np.hstack((reu,data410))

# %%
dataw1 = np.loadtxt("0-500upp.out")
dataw2 = np.loadtxt("0-700.out")
dataw3 = np.loadtxt("0-500upp1.out")
dw = dataw2[:,0:50]
dw[16:30,:]=dataw1
dw[-1,:]=dataw3

# %%
dw[-1,:]
# Out:
# array([-0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  2.85985669e-05,
#         9.87097429e-04,  4.75947833e-03, -4.13372145e-03, -4.13218167e-02,
#        -5.42348249e-01, -1.10102096e+00, -1.00790018e-01, -1.85953988e-01,
#         2.26870428e-01,  1.12328140e-02])

# %%
reu = np.hstack((dw,reu))

# %%
reu.shape
# Out:
# (30, 360)

# %%
#np.savetxt('midlef.out',reu)

# %%
# lower layer
datalow1 = np.loadtxt("700-900low.out")
datalow2 = np.loadtxt("500-700low.out")
datalow = np.zeros([17,360])
datalow[datalow==0]=np.nan
datalow[:,70:90]= datalow1
datalow[:,50:70]= datalow2

# %%
datalow3 = np.loadtxt("150-190.out")
datalow4 = np.loadtxt("110-150.out")
datalow5 = np.loadtxt("70-110.out")
datalow[13:17,90:100]= datalow3
datalow[9:13,90:100]= datalow4
datalow[5:9,90:100]= datalow5

# %%
# lower layer
low1 = np.loadtxt("2700low1.out")
low2 = np.loadtxt("2700low2.out")
low3 = np.loadtxt("2700low3.out")
low4 = np.loadtxt("2700low4.out")
low5 = np.loadtxt("2700low5.out")
low6 = np.loadtxt("2700low6.out")
low7 = np.loadtxt("2700low7.out")
low8 = np.loadtxt("2700low8.out")
low9 = np.loadtxt("2700low9.out")

datalow[0:2,270:290]= low1
datalow[2:4,270:290]= low2
datalow[4:6,270:290]= low3
datalow[6:8,270:290]= low4
datalow[8:10,270:290]= low5
datalow[10:12,270:290]= low6
datalow[12:14,270:290]= low7
datalow[14:16,270:290]= low8
datalow[16:17,270:290]= low9

# %%
# lower layer
elow1 = np.loadtxt("2900low1.out")
elow2 = np.loadtxt("2900low2.out")
elow3 = np.loadtxt("2900low3.out")
elow4 = np.loadtxt("2900low4.out")
elow5 = np.loadtxt("2900low5.out")
elow6 = np.loadtxt("2900low6.out")
elow7 = np.loadtxt("2900low7.out")
elow8 = np.loadtxt("2900low8.out")
elow9 = np.loadtxt("2900low9.out")

datalow[0:2,290:310]= elow1
datalow[2:4,290:310]= elow2
datalow[4:6,290:310]= elow3
datalow[6:8,290:310]= elow4
datalow[8:10,290:310]= elow5
datalow[10:12,290:310]= elow6
datalow[12:14,290:310]= elow7
datalow[14:16,290:310]= elow8
datalow[16:17,290:310]= elow9

# %%
# lower layer
eelow1 = np.loadtxt("3100low1.out")
eelow2 = np.loadtxt("3100low2.out")
eelow3 = np.loadtxt("3100low3.out")
eelow4 = np.loadtxt("3100low4.out")
eelow5 = np.loadtxt("3100low5.out")
eelow6 = np.loadtxt("3100low6.out")
eelow7 = np.loadtxt("3100low7.out")
eelow8 = np.loadtxt("3100low8.out")
eelow9 = np.loadtxt("3100low9.out")

datalow[0:2,310:330]= eelow1
datalow[2:4,310:330]= eelow2
datalow[4:6,310:330]= eelow3
datalow[6:8,310:330]= eelow4
datalow[8:10,310:330]= eelow5
datalow[10:12,310:330]= eelow6
datalow[12:14,310:330]= eelow7
datalow[14:16,310:330]= eelow8
datalow[16:17,310:330]= eelow9

# %%
# lower layer
weelow1 = np.loadtxt("3300low90-110.out")
weelow2 = np.loadtxt("3300low110-150.out")
weelow3 = np.loadtxt("3300low130-150.out")
weelow4 = np.loadtxt("3300low150-170.out")
weelow5 = np.loadtxt("3300low170-190.out")

datalow[7:9,330:350]= weelow1
datalow[9:11,330:350]= weelow2
datalow[11:13,330:350]= weelow3
datalow[13:15,330:350]= weelow4
datalow[15:17,330:350]= weelow5

# %%
# lower layer
tweelow1 = np.loadtxt("110-150f3500.out")
tweelow2 = np.loadtxt("150-190f3500.out")

datalow[9:13,350:360]= tweelow1
datalow[13:17,350:360]= tweelow2

# %%
# lower layer
qweelow1 = np.loadtxt("0low90-110.out")
qweelow2 = np.loadtxt("0low110-150.out")
qweelow3 = np.loadtxt("0low130-150.out")
qweelow4 = np.loadtxt("0low150-170.out")
qweelow5 = np.loadtxt("0low170-190.out")

datalow[7:9,0:20]= qweelow1
datalow[9:11,0:20]= qweelow2
datalow[11:13,0:20]= qweelow3
datalow[13:15,0:20]= qweelow4
datalow[15:17,0:20]= qweelow5

# %%
# lower layer
aqweelow1 = np.loadtxt("20low90-110.out")
aqweelow2 = np.loadtxt("20low110-150.out")
aqweelow3 = np.loadtxt("20low130-150.out")
aqweelow4 = np.loadtxt("20low150-170.out")
aqweelow5 = np.loadtxt("20low170-190.out")

datalow[7:9,20:40]= aqweelow1
datalow[9:11,20:40]= aqweelow2
datalow[11:13,20:40]= aqweelow3
datalow[13:15,20:40]= aqweelow4
datalow[15:17,20:40]= aqweelow5

# %%
reu = np.vstack((datalow,reu))

# %%
result = np.zeros([47,361])
ss = reu[:,0]
result[:,0:360] = reu
result[:,360] = ss

# %%
nice_cmap=sns.diverging_palette(245, 15, n=13,as_cmap=True)
#nice_cmap=sns.diverging_palette(245, 10, n=10,as_cmap=True)
lev_cmap = nice_cmap([1,30,50,70,100,150,170,180,210,230,240]) 
new_cmap = cols.ListedColormap(lev_cmap,"praj_cmap")
#nice_levels = [-25,-20,-15,-10,-5,0,5,10,15,20,25]
nice_levels = [-40,-30,-20,-10,0,10,20,30,40]
#nice_levels = [-40,-20,0,20,40]
norm = mpl.colors.BoundaryNorm(nice_levels, new_cmap.N)
#********************************************************************

plt.figure(figsize=(25,25))
my_font = {'fontname':'Cambria', 'size':'45'}
# set the mapping range
map = Basemap(projection='aeqd', lat_0 = -90, lon_0 = 0,area_thresh = 100,\
                     width = 7350000,height = 7350000,resolution ='h') 
#############################################
##width = 2500000,height = 1500000
##lat_0 = -65, lon_0 = 0
#############################################
map.drawcoastlines()
map.fillcontinents(color = 'lightgrey')
map.drawmapboundary(color='black')
 
map.drawparallels(np.arange(-90,91,5),labels=[1,0,0,0],**my_font)
map.drawmeridians(np.arange(-180,180,10),labels=[0,0,1,0],**my_font)

x,y=map(lont1,latt1)
#x2,y2=map(lont2,latt2)
CP = map.contourf(x,y,result,levels = nice_levels,cmap = new_cmap,norm =norm,spacing = 'uniform',extend='both')
#CP = map.contourf(x2,y2,dataR[:3,:],levels = nice_levels,cmap = new_cmap,norm =norm,spacing = 'uniform',extend='both')
CP.cmap.set_over('firebrick')
CP.cmap.set_under('darkblue')

#CS=map.contour(x,y,plotvar,[700],colors = 'r', linestyles = 'solid',linewidths=1)
#plt.clabel(CS, inline=0.1, fontsize=30)
#cbar =map.colorbar(CP,extend='both',extendfrac='auto',extendrect='True')
cbar =map.colorbar(CP,extendfrac='auto',ticks= nice_levels)
#cbar.minorticks_on()
cbar.ax.tick_params(labelsize=40)
cbar.set_label('(%)', **my_font)
#cbar.set_label('($^\circ$C)', **my_font)
plt.xlabel("Regression of September sea-ice concentration onto the global-mean SST",**my_font)
plt.savefig("regression.png",bbox_inches='tight')
# Out:
# /scratch/user/xiliangdiao/.conda/envs/python3/lib/python3.6/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   from ipykernel import kernelapp as app
# /scratch/user/xiliangdiao/.conda/envs/python3/lib/python3.6/site-packages/ipykernel_launcher.py:29: UserWarning: The following kwargs were not used by contour: 'spacing'
# findfont: Font family ['Cambria'] not found. Falling back to DejaVu Sans.

# %%
reu.shape
# Out:
# (47, 360)

# %%
data110[6,:]
# Out:
# array([-1.42122077, -2.29683675, -3.35532768, -4.31011256, -5.35093953,
#        -5.15828404, -6.83656644, -6.31098431, -8.08652184, -9.11840636,
#        -9.43025198, -8.54872218, -9.73226051, -9.11240782, -7.71935988,
#        -7.85146672, -6.52022966, -5.70658087, -4.03328684, -1.41443261])

# %%
np.savetxt('final1.out',reu)

# %%
reu.shape
# Out:
# (47, 360)
