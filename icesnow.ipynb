# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
icesnow = np.loadtxt("icesnow.out")
iceevap = np.loadtxt("iceevap.out")
icesnow2 = np.loadtxt("icesnow2.out")

# %%
icenet = icesnow+iceevap

# %%
plt.plot(icesnow2)

# %%
wspxx = np.loadtxt("wspxx2.out")
mrpxx = np.loadtxt("mrpxx2.out")
#arpxx = np.loadtxt("arpxx2.out")
t = np.arange(2,348,1)

# %%
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,20), dpi=100)
################################################################
################################################################
t = np.arange(0,350,1)
ax1 = fig.add_axes([0.1, 0.9, 0.8, 0.2],
                    xticklabels=[],ylim=(0.000004, 0.000021))

ax1.plot(icesnow,'blue',linewidth=4)

#ax1.fill_between(t,premean,pre,where=pre < premean,facecolor='purple', alpha=1)
#plt.hlines(premean*3600*24*100/997, 0, 350, colors = "blue",linestyles = "dashed")
#plt.vlines(arpxx, premean*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(mrpxx, 0.0000058*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(wspxx, 0.0000058*3600*24*100/997, 0.000024*3600*24*100/997, colors = "grey",linewidth=5)
plt.ylabel('Precipitation (cm/day)',**my_font)
plt.axis("tight")

plt.title('Snow fall rate from coupler (ice) 5 year running mean', fontsize=25)

ax1.set(ylim=(0.13,0.175),xlim=(0, 350))
ax = plt.gca()
#ax.yaxis.get_major_formatter().set_powerlimits((0,1))
ax.yaxis.get_offset_text().set_fontsize(16)
plt.yticks(**my_font)
#############################
plt.savefig("icesnow.png",bbox_inches='tight',dpi=fig.dpi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-71648aea0d2c> in <module>
#       1 my_font = {'fontname':'Cambria', 'size':'16'}
#       2 ##################################################################
# ----> 3 fig = plt.figure(figsize=(20,20), dpi=100)
#       4 ################################################################
#       5 ################################################################
#
# NameError: name 'plt' is not defined

# %%
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,20), dpi=100)
################################################################
################################################################
t = np.arange(0,350,1)
ax1 = fig.add_axes([0.1, 0.9, 0.8, 0.2],
                    xticklabels=[],ylim=(0.000004, 0.000021))

ax1.plot(icenet,'red',linewidth=4)

#ax1.fill_between(t,premean,pre,where=pre < premean,facecolor='purple', alpha=1)
#plt.hlines(premean*3600*24*100/997, 0, 350, colors = "blue",linestyles = "dashed")
#plt.vlines(arpxx, premean*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(mrpxx, 0.0000058*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(wspxx, 0.0000058*3600*24*100/997, 0.000024*3600*24*100/997, colors = "grey",linewidth=5)
plt.ylabel('Precipitation (cm/day)',**my_font)
plt.axis("tight")

plt.title('Snow fall rate from coupler (ice) 5 year running mean', fontsize=25)

ax1.set(ylim=(0.11,0.16),xlim=(0, 350))
ax = plt.gca()
#ax.yaxis.get_major_formatter().set_powerlimits((0,1))
ax.yaxis.get_offset_text().set_fontsize(16)
plt.yticks(**my_font)
# Out:
# (array([0.11, 0.12, 0.13, 0.14, 0.15, 0.16]),
#  <a list of 6 Text yticklabel objects>)

# %%
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,20), dpi=100)
################################################################
################################################################
t = np.arange(0,350,1)
ax1 = fig.add_axes([0.1, 0.9, 0.8, 0.2],
                    xticklabels=[],ylim=(0.000004, 0.000021))

ax1.plot(iceevap,'blue',linewidth=4)

#ax1.fill_between(t,premean,pre,where=pre < premean,facecolor='purple', alpha=1)
#plt.hlines(premean*3600*24*100/997, 0, 350, colors = "blue",linestyles = "dashed")
#plt.vlines(arpxx, premean*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(mrpxx, 0.0000058*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(wspxx, 0.0000058*3600*24*100/997, 0.000024*3600*24*100/997, colors = "grey",linewidth=5)
plt.ylabel('Precipitation (cm/day)',**my_font)
plt.axis("tight")

plt.title('Snow fall rate from coupler (ice) 5 year running mean', fontsize=25)

#ax1.set(ylim=(0.013,0.0175),xlim=(0, 350))
ax = plt.gca()
#ax.yaxis.get_major_formatter().set_powerlimits((0,1))
ax.yaxis.get_offset_text().set_fontsize(16)
plt.yticks(**my_font)
# Out:
# (array([-0.05,  0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25]),
#  <a list of 7 Text yticklabel objects>)

# %%
#t = np.arange(0,4176,12)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,20), dpi=100)
################################################################
################################################################
t = np.arange(0,350,1)
ax1 = fig.add_axes([0.1, 0.9, 0.8, 0.2],
                    xticklabels=[],ylim=(0.000004, 0.000021))

ax1.plot(icesnow,'blue',linewidth=4)

#ax1.fill_between(t,premean,pre,where=pre < premean,facecolor='purple', alpha=1)
#plt.hlines(premean*3600*24*100/997, 0, 350, colors = "blue",linestyles = "dashed")
#plt.vlines(arpxx, premean*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(mrpxx, 0.0000058*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(wspxx, 0.0000058*3600*24*100/997, 0.000024*3600*24*100/997, colors = "grey",linewidth=5)
plt.ylabel('Snow (cm/day)',**my_font)
plt.axis("tight")

plt.title('Snow fall rate from coupler (ice) 5 year running mean', fontsize=25)

ax1.set(ylim=(0.13,0.175),xlim=(0, 350))
ax = plt.gca()
#ax.yaxis.get_major_formatter().set_powerlimits((0,1))
ax.yaxis.get_offset_text().set_fontsize(16)
plt.yticks(**my_font)

###########################################
ax2 = fig.add_axes([0.1, 0.7, 0.8, 0.2],
                    xticklabels=[],ylim=(0.000004, 0.000021))

ax2.plot(iceevap,'black',linewidth=4)

#ax1.fill_between(t,premean,pre,where=pre < premean,facecolor='purple', alpha=1)
#plt.hlines(premean*3600*24*100/997, 0, 350, colors = "blue",linestyles = "dashed")
#plt.vlines(arpxx, premean*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(mrpxx, -0.018,-0.01, colors = "lightgrey",linewidth=5)
plt.vlines(wspxx, -0.018,-0.01, colors = "grey",linewidth=5)
plt.ylabel('Evaporation (cm/day)',**my_font)
plt.axis("tight")

plt.title('Snow evaporation rate from coupler (ice) 5 year running mean', fontsize=25)
ax2.set(ylim=(-0.018,-0.01),xlim=(0, 350))
ax2 = plt.gca()
#ax2.yaxis.get_major_formatter().set_powerlimits((0,1))

ax2.yaxis.set_label_position('right')
ax2.yaxis.set_ticks_position('right')
ax2.yaxis.get_offset_text().set_fontsize(25)
plt.yticks(**my_font)
#plt.title('(b)', fontsize=25)
################################################################
#####################################################################
ax3 = fig.add_axes([0.1, 0.5, 0.8, 0.2],
                   xticklabels=[],ylim=(34, 34.6))
ax3.plot(icenet,'red',linewidth=4)

#ax1.fill_between(t,premean,pre,where=pre < premean,facecolor='purple', alpha=1)
#plt.hlines(premean*3600*24*100/997, 0, 350, colors = "blue",linestyles = "dashed")
#plt.vlines(arpxx, premean*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(mrpxx, 0.0000058*3600*24*100/997, 0.000024*3600*24*100/997, colors = "lightgrey",linewidth=5)
plt.vlines(wspxx, 0.0000058*3600*24*100/997, 0.000024*3600*24*100/997, colors = "grey",linewidth=5)
plt.ylabel('Snow-Evap (cm/day)',**my_font)
plt.axis("tight")

plt.title('Snow-Evaporation rate from coupler (ice) 5 year running mean', fontsize=25)

ax3.set(ylim=(0.11,0.16),xlim=(0, 350))
ax = plt.gca()
#ax.yaxis.get_major_formatter().set_powerlimits((0,1))
ax.yaxis.get_offset_text().set_fontsize(16)
plt.yticks(**my_font)
plt.savefig("netsonw.png",bbox_inches='tight',dpi=fig.dpi)
