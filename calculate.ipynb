# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
#data1 = np.loadtxt("21-51.out")
#data2 = np.loadtxt("51-81.out")
#data3 = np.loadtxt("81-111.out")
#data4 = np.loadtxt("111-141.out")
#data5 = np.loadtxt("141-171.out")
#data6 = np.loadtxt("171-201.out")
#data7 = np.loadtxt("201-231.out")
#data8 = np.loadtxt("231-261.out")
#data9 = np.loadtxt("261-291.out")
#data10 = np.loadtxt("291-331.out")

# %%
#result = np.zeros(3720)
#result[0:360] =data1
#result[360:720] =data2
#result[720:1080] =data3
#result[1080:1440] =data4
#result[1440:1800] =data5
#result[1800:2160] =data6
#result[2160:2520] =data7
#result[2520:2880] =data8
#result[2880:3240] =data9
#result[3240:3720] =data10
#dataweddle = np.loadtxt("maudrisecurl.out")
#result = np.zeros(3720)
#result[:] = dataweddle

# %%
data1
# Out:
# array([-0.00081668, -0.00108112, -0.00101712, -0.00088708, -0.00122733,
#        -0.00071641, -0.00091112, -0.00126388, -0.00137445, -0.00130117,
#        -0.00098236, -0.0011524 , -0.00078284, -0.00089623, -0.00114655,
#        -0.00110484, -0.00124774, -0.00111964, -0.00138387, -0.00125887,
#        -0.00107162, -0.00119595, -0.00092183, -0.00057719, -0.00087288,
#        -0.0009084 , -0.00119072, -0.00135054, -0.00112366, -0.00114155,
#        -0.00191526, -0.00120452, -0.00109422, -0.0011967 , -0.00092672,
#        -0.00072996, -0.00080459, -0.0010607 , -0.00086332, -0.00075651,
#        -0.00106042, -0.00129629, -0.0012275 , -0.00124351, -0.00113066,
#        -0.00120345, -0.0011509 , -0.00080845, -0.00063492, -0.00072001,
#        -0.00113478, -0.00120877, -0.00128641, -0.00111508, -0.00110817,
#        -0.00111821, -0.00121002, -0.00106381, -0.00107523, -0.00091616,
#        -0.00084758, -0.00118344, -0.00123009, -0.00134906, -0.00114436,
# ...

# %%
data1 = np.loadtxt("21-61new.out")
data2 = np.loadtxt("61-101new.out")
data3 = np.loadtxt("101-141new.out")
data4 = np.loadtxt("141-181new.out")
data5 = np.loadtxt("181-221new.out")
data6 = np.loadtxt("221-261new.out")
data7 = np.loadtxt("261-291new.out")
data8 = np.loadtxt("291-321new.out")
data9 = np.loadtxt("321-331new.out")
result = np.zeros(3720)
result[0:480] =data1
result[480:960] =data2
result[960:1440] =data3
result[1440:1920] =data4
result[1920:2400] =data5
result[2400:2880] =data6
result[2880:3240] =data7
result[3240:3600] =data8
result[3600:3720] =data9

# %%
result[1254] = (result[1253] + result[1256])/2
result[1255] = (result[1253] + result[1256])/2

# %%
1254/12
# Out:
# 104.5

# %%
np.where(result ==0)
# Out:
# (array([], dtype=int64),)

# %%
anom = result.reshape(310,12)

# %%
anom[:,0].mean()
# Out:
# -0.0008129078941391982

# %%
result[60]
# Out:
# -0.0008475807776160204

# %%
anom.mean(axis =1)[0]
# Out:
# -0.0010609260908788537

# %%
result[36:48].mean()
# Out:
# -0.001050525040283623

# %%
err = anom.mean(axis =0)

# %%
anomaly = anom - err

# %%
anom[0] - anomaly[0]
# Out:
# array([-0.00081291, -0.00098061, -0.00105163, -0.001104  , -0.00107078,
#        -0.00112697, -0.00122293, -0.00117565, -0.00120731, -0.00111297,
#        -0.00103273, -0.00083581])

# %%
# this is the 300 yearly mean data (1mean, 2mean, 3mean)
err.mean()
# Out:
# -0.0010611906270219138

# %%
# 12 months average pattern (300years)
plt.plot(err)

# %%
anomaly2 = anomaly.reshape(3720)

# %%
## result is the actually value of the wind stress curl
## anomaly2 is the anomaly value (1-1mean, 2-2mean,....)
## So, result - anomaly2 = (1mean, 2mean.....12mean, 1mean, 2 mean,... 12mean...)
(result - anomaly2)[:36]
# Out:
# array([-0.00081291, -0.00098061, -0.00105163, -0.001104  , -0.00107078,
#        -0.00112697, -0.00122293, -0.00117565, -0.00120731, -0.00111297,
#        -0.00103273, -0.00083581, -0.00081291, -0.00098061, -0.00105163,
#        -0.001104  , -0.00107078, -0.00112697, -0.00122293, -0.00117565,
#        -0.00120731, -0.00111297, -0.00103273, -0.00083581, -0.00081291,
#        -0.00098061, -0.00105163, -0.001104  , -0.00107078, -0.00112697,
#        -0.00122293, -0.00117565, -0.00120731, -0.00111297, -0.00103273,
#        -0.00083581])

# %%
#do 60 monthly mean to anomaly2 and reesult
# get the result

#ww1 = np.convolve(anomaly2, np.ones((60,))/60, mode='valid')
ww2 = np.convolve(result, np.ones((60,))/60, mode='valid')

# %%
## The difference is exactaly the same
## So, the two plot is exactly the sa
mean = np.nanmean(ww2)
fin = ww2 -mean

# %%
ww2.mean()*0.0001
# Out:
# -1.0615204738718917e-07

# %%
my_font = {'fontname':'Cambria', 'size':'13'}

# %%
result[:24]-anomaly2[:24]
# Out:
# array([-0.00081291, -0.00098061, -0.00105163, -0.001104  , -0.00107078,
#        -0.00112697, -0.00122293, -0.00117565, -0.00120731, -0.00111297,
#        -0.00103273, -0.00083581, -0.00081291, -0.00098061, -0.00105163,
#        -0.001104  , -0.00107078, -0.00112697, -0.00122293, -0.00117565,
#        -0.00120731, -0.00111297, -0.00103273, -0.00083581])

# %%
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1, 0.1, 0.7, 0.7])
ax0.plot(0.0001*anomaly2[0:24])
#ax0.plot(0.0001*ww,"r*")
#plt.hlines(-1.060805584253882e-07, 0, 3720, colors = "g",linestyles = "dashed")
#plt.hlines(-1.0594455480825744e-07, 0, 319, colors = "g",linestyles = "dashed")
#plt.hlines(ww2, 0, 40, colors = "r",linestyles = "dashed")
#plt.yticks(np.arange(-1.175,-0.95,0.025), ['-1.175', '-1.150','-1.125', '-1.100', '-1.075', '-1.050','-1.025','-1','-0.975','-0.95'],**my_font)
#plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
#                             '180','200','220', '240', '260','280','300','320'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Month',**my_font)
plt.ylabel('Wind stress curl anomaly(N/m$^3$)',**my_font)
ax0.set_title('Averaged over the Weddell Sea (55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S)',**my_font)
#ax0.set_title('Averaged the same region with SSH (70$^\circ$S - 50$^\circ$S, 55$^\circ$W - 40$^\circ$E)',**my_font)

plt.savefig("windcurl5.png")
# Out:
# findfont: Font family ['Cambria'] not found. Falling back to DejaVu Sans.

# %%
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1, 0.1, 0.7, 0.7])
ax0.plot(0.0001*result[0:24])
#ax0.plot(0.0001*ww,"r*")
#plt.hlines(-1.060805584253882e-07, 0, 3720, colors = "g",linestyles = "dashed")
#plt.hlines(-1.0594455480825744e-07, 0, 319, colors = "g",linestyles = "dashed")
#plt.hlines(ww2, 0, 40, colors = "r",linestyles = "dashed")
#plt.yticks(np.arange(-1.175,-0.95,0.025), ['-1.175', '-1.150','-1.125', '-1.100', '-1.075', '-1.050','-1.025','-1','-0.975','-0.95'],**my_font)
#plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
#                             '180','200','220', '240', '260','280','300','320'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Month',**my_font)
plt.ylabel('Wind stress curl(N/m$^3$)',**my_font)
ax0.set_title('Averaged over the Weddell Sea (55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S)',**my_font)
#ax0.set_title('Averaged the same region with SSH (70$^\circ$S - 50$^\circ$S, 55$^\circ$W - 40$^\circ$E)',**my_font)

plt.savefig("windcurl4.png")

# %%
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1, 0.1, 0.7, 0.7])
ax0.plot(0.0001*err)
#ax0.plot(0.0001*ww,"r*")
#plt.hlines(-1.060805584253882e-07, 0, 3720, colors = "g",linestyles = "dashed")
#plt.hlines(-1.0594455480825744e-07, 0, 319, colors = "g",linestyles = "dashed")
#plt.hlines(ww2, 0, 40, colors = "r",linestyles = "dashed")
#plt.yticks(np.arange(-1.175,-0.95,0.025), ['-1.175', '-1.150','-1.125', '-1.100', '-1.075', '-1.050','-1.025','-1','-0.975','-0.95'],**my_font)
#plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
#                             '180','200','220', '240', '260','280','300','320'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Month',**my_font)
plt.ylabel('Wind stress curl(N/m$^3$)',**my_font)
ax0.set_title('Averaged over the Weddell Sea (55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S)',**my_font)
#ax0.set_title('Averaged the same region with SSH (70$^\circ$S - 50$^\circ$S, 55$^\circ$W - 40$^\circ$E)',**my_font)

plt.savefig("windcur54.png")

# %%
t = np.arange(0,3720,12)
my_font = {'fontname':'Cambria', 'size':'13'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1, 0.1, 0.7, 0.7])
ax0.plot(0.0001*ww1)
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
                            '180','200','220', '240', '260','280','300','320'],**my_font)
plt.hlines(0, 0, 3720, colors = "g",linestyles = "dashed")
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Wind stress curl anomaly(N/m$^3$)',**my_font)
##################################################################################################
ax2 = ax0.twinx() 
ax2.plot(t, resultweddle,'r')
my_y_ticks = np.arange(0, 120, 20)
plt.ylim(-20, 120)
plt.yticks(my_y_ticks,**my_font)
plt.ylabel('Weddle Sea ice contration (%)',**my_font)

ax0.set_title('Averaged over the Weddell Sea (55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S)',**my_font)
#####################################################################################
#ax0.plot(0.0001*ww,"r*")
#plt.hlines(-1.0594455480825744e-07, 0, 319, colors = "g",linestyles = "dashed")
#plt.hlines(ww2, 0, 40, colors = "r",linestyles = "dashed")
#plt.yticks(np.arange(-1.175,-0.95,0.025), ['-1.175', '-1.150','-1.125', '-1.100', '-1.075', '-1.050','-1.025','-1','-0.975','-0.95'],**my_font)
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
                            '180','200','220', '240', '260','280','300','320'],**my_font)
#ax0.set_title('Averaged the same region with SSH (70$^\circ$S - 50$^\circ$S, 55$^\circ$W - 40$^\circ$E)',**my_font)
#np.savetxt('ww1.out', 0.0001*final)
plt.savefig("windcur35.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d86cb282234c> in <module>
#       4 fig = plt.figure(figsize=(20,5), dpi=100)
#       5 ax0 = fig.add_axes([0.1, 0.1, 0.7, 0.7])
# ----> 6 ax0.plot(0.0001*ww1)
#       7 plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
#       8                             '180','200','220', '240', '260','280','300','320'],**my_font)
#
# NameError: name 'ww1' is not defined

# %%
dataweddle = np.loadtxt("maudrise.out")
resultmaudrise = np.zeros(310)
resultmaudrise[:] = dataweddle
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-ae307879aaee> in <module>
#       1 dataweddle = np.loadtxt("maudrise.out")
#       2 resultmaudrise = np.zeros(310)
# ----> 3 resultmaudrise[:] = dataweddle
#
# ValueError: could not broadcast input array from shape (720) into shape (310)

# %%
t = np.arange(0,3720,12)
my_font = {'fontname':'Cambria', 'size':'13'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1, 0.1, 0.7, 0.7])
ax0.plot(0.0001*fin)
#plt.hlines(0, 0, 3720, colors = "g",linestyles = "dashed")
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160','180','200','220', '240', '260','280','300','320'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Wind stress curl anomaly(N/m$^3$)',**my_font)

##################################################################################################
#ax2 = ax0.twinx() 
#ax2.plot(t, resultmaudrise,'r')

#my_y_ticks = np.arange(0, 120, 20)
#plt.ylim(-20, 120)
#plt.yticks(my_y_ticks,**my_font)

#plt.ylabel('Maud Rise ice contration (%)',**my_font)

ax0.set_title('Averaged over the Weddell Sea (55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S)',**my_font)
#####################################################################################

#plt.savefig("windcur45.png")
# Out:
# Text(0.5, 1.0, 'Averaged over the Weddell Sea (55$^\\circ$W - 40$^\\circ$E, 50$^\\circ$S - 70$^\\circ$S)')

# %%
np.save(file="curl.npy", arr=0.1*fin)

# %%
std = np.std(ww2)*0.0001
t = np.arange(36,3697,1)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(t,0.0001*fin,'red',linewidth=3)
#########################################
plt.hlines(0, 0, 3720, colors = "blue",linestyles = "dashed")
##########################################################################
plt.axvspan(0,(30-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((27-20)*12 +9,(28-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((30-20)*12 + 9,(39-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((47-20)*12 + 9,(49-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((39-20)*12 + 9,(40-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((40-20)*12 + 9,(41-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((41-20)*12 + 9,(42-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((42-20)*12 + 9,(44-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((44-20)*12 + 9,(50-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((50-20)*12 + 9,(69-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((56-20)*12 + 9,(57-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((69-20)*12 + 9,(70-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((70-20)*12 + 9,(72-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((72-20)*12 + 9,(74-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((74-20)*12 + 9,(80-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((79-20)*12 + 9,(81-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((81-20)*12 + 9,(85-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((85-20)*12 + 9,(86-20)*12 +9,facecolor='blue', alpha=1)

plt.axvspan((86-20)*12 + 9,(94-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((91-20)*12 + 9,(92-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((94-20)*12 + 9,(100-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((96-20)*12 + 9,(97-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((97-20)*12 + 9,(98-20)*12 +9,facecolor='yellow', alpha=1)

plt.axvspan((100-20)*12 + 9,(111-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((106-20)*12 + 9,(108-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((108-20)*12 + 9,(110-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((111-20)*12 + 9,(118-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((113-20)*12 + 9,(114-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((116-20)*12 + 9,(118-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((118-20)*12 + 9,(119-20)*12 +9,facecolor='grey', alpha=1)

plt.axvspan((119-20)*12 + 9,(135-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((119-20)*12 + 9,(121-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((130-20)*12 + 9,(131-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((133-20)*12 + 9,(134-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((134-20)*12 + 9,(138-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((138-20)*12 + 9,(149-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((140-20)*12 + 9,(141-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((141-20)*12 + 9,(142-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((142-20)*12 + 9,(143-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((143-20)*12 + 9,(144-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((144-20)*12 + 9,(147-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((147-20)*12 + 9,(148-20)*12 +9,facecolor='blue', alpha=1)
#plt.axvspan((142-20)*12 + 9,(149-20)*12 +9,facecolor='lightgreen', alpha=1)

plt.axvspan((149-20)*12 + 9,(152-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((152-20)*12 + 9,(160-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((152-20)*12 + 9,(154-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((157-20)*12 + 9,(160-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((160-20)*12 + 9,(168-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((167-20)*12 + 9,(200-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((174-20)*12 + 9,(196-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((196-20)*12 + 9,(199-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((181-20)*12 + 9,(183-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((200-20)*12 + 9,(203-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((203-20)*12 + 9,(249-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((210-20)*12 + 9,(211-20)*12 +9,facecolor='blue', alpha=1)

plt.axvspan((212-20)*12 + 9,(217-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((223-20)*12 + 9,(226-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((231-20)*12 + 9,(232-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((233-20)*12 + 9,(249-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((248-20)*12 + 9,(249-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((249-20)*12 + 9,(252-20)*12 +9,facecolor='grey', alpha=1)

plt.axvspan((252-20)*12 + 9,(290-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((254-20)*12 + 9,(256-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((257-20)*12 + 9,(258-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((258-20)*12 + 9,(263-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((261-20)*12 + 9,(262-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((264-20)*12 + 9,(265-20)*12 +9,facecolor='blue', alpha=1)

plt.axvspan((266-20)*12 + 9,(290-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((290-20)*12 + 9,(300-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((300-20)*12 + 9,(321-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((304-20)*12 + 9,(319-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((321-20)*12 + 9,(330-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((326-20)*12 + 9,(330-20)*12 +9,facecolor='green', alpha=1)
std = np.std(ww2)*0.0001
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160','180','200','220', '240', '260','280','300','320'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Wind stress curl anomaly(N/m$^3$)',color= 'red',**my_font)
plt.axis("tight")
ax0.set(ylim=(-0.000000012, 0.000000012),xlim=(0, 3720))
ax0.set_title('Averaged over the Weddell Sea (55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S)',**my_font)
plt.savefig("windcurlice.png",bbox_inches='tight',dpi=fig.dpi)

# %%
std = np.std(ww2)*0.0001
t = np.arange(36,3697,1)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(t[1593:3697],0.0001*fin[1593:3697],'red',linewidth=3)
#########################################
plt.hlines(0, 1593, 3720, colors = "blue",linestyles = "dashed")
##########################################################################

plt.axvspan((152-20)*12 + 9,(160-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((152-20)*12 + 9,(154-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((157-20)*12 + 9,(160-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((160-20)*12 + 9,(168-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((167-20)*12 + 9,(200-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((174-20)*12 + 9,(196-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((196-20)*12 + 9,(199-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((181-20)*12 + 9,(183-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((200-20)*12 + 9,(203-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((203-20)*12 + 9,(249-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((210-20)*12 + 9,(211-20)*12 +9,facecolor='blue', alpha=1)

plt.axvspan((212-20)*12 + 9,(217-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((223-20)*12 + 9,(226-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((231-20)*12 + 9,(232-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((233-20)*12 + 9,(249-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((248-20)*12 + 9,(249-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((249-20)*12 + 9,(252-20)*12 +9,facecolor='grey', alpha=1)

plt.axvspan((252-20)*12 + 9,(290-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((254-20)*12 + 9,(256-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((257-20)*12 + 9,(258-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((258-20)*12 + 9,(263-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((261-20)*12 + 9,(262-20)*12 +9,facecolor='blue', alpha=1)
plt.axvspan((264-20)*12 + 9,(265-20)*12 +9,facecolor='blue', alpha=1)

plt.axvspan((266-20)*12 + 9,(290-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((290-20)*12 + 9,(300-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((300-20)*12 + 9,(321-20)*12 +9,facecolor='green', alpha=1)
plt.axvspan((304-20)*12 + 9,(319-20)*12 +9,facecolor='yellow', alpha=1)
plt.axvspan((321-20)*12 + 9,(330-20)*12 +9,facecolor='grey', alpha=1)
plt.axvspan((326-20)*12 + 9,(330-20)*12 +9,facecolor='green', alpha=1)
#std = np.std(ww2)*0.0001
plt.xticks(range(1593,3697,240), ['150','170','190','210', '230', '250','270','290','310','330'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Wind stress curl anomaly(N/m$^3$)',color= 'red',**my_font)
plt.axis("tight")
ax0.set(ylim=(-0.000000012, 0.000000012),xlim=(0, 3720))
ax0.set_title('Averaged over the Weddell Sea (55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S)',**my_font)
plt.savefig("windcurlice.png",bbox_inches='tight',dpi=fig.dpi)

# %%
(152-20)*12 + 9 -3697

# %%
std = np.std(ww2)*0.0001
#t = np.arange(0,3181,1)
my_font = {'fontname':'Cambria', 'size':'16'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1,0.1,0.7,0.7])
ax0.plot(0.0001*fin,'blue',linewidth=3)
plt.axhspan(std,0.000000012,facecolor='lightgreen', alpha=1)
plt.axhspan(-std,std,facecolor='lightblue', alpha=1)
plt.axhspan(-0.000000012,-std,facecolor='yellow', alpha=1)
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160',\
                            '180','200','220', '240', '260','280','300','320'],**my_font)
#plt.yticks(np.arange(-0.6,0.6,0.2), ['-0.6', '-0.4', '-0.2', '0','0.2','0.4','0.6'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Wind stress curl anomaly(N/m$^3$)',**my_font)
plt.axis("tight")
ax0.set(ylim=(-0.000000012, 0.000000012),xlim=(0, 3720))
ax0.set_title('Averaged over the Weddell Sea (55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S)',**my_font)
plt.savefig("windcurl.png",bbox_inches='tight',dpi=fig.dpi)

# %%
y=[1,2,3,10,5,6,7,8,9]

# %%
result = ww1

# %%
final = np.zeros((310))
years = np.arange(0,3720,12)
i = 0
for ii in years:
    final[i] = (result[ii]+result[ii+1]+result[ii+2]+result[ii+3]+result[ii+4]+result[ii+5]+result[ii+6]+result[ii+7]+result[ii+8]+result[ii+9]+result[ii+10]+result[ii+11])/12
    #final[i,:] = (result[ii,:]+result[ii+1,:]+result[ii+2,:])/3
    i = i+1

# %%
ww3 = np.convolve(final, np.ones((5,))/5, mode='valid')

# %%
t = np.arange(0,3684,12)
my_font = {'fontname':'Cambria', 'size':'13'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1, 0.1, 0.7, 0.7])
ax0.plot(0.0001*ww2)
plt.hlines(-2.2945436653556553e-07, 0, 3720, colors = "g",linestyles = "dashed")
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160','180','200','220', '240', '260','280','300','320'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Wind stress curl (N/m$^3$)',**my_font)

ax0.invert_yaxis()
ax0.set_title('Averaged over Maud Rise (0$^\circ$ - 10$^\circ$E, 63$^\circ$S - 67$^\circ$S)',**my_font)
#####################################################################################
plt.savefig("windcur.png")

# %%
dataweddle = np.loadtxt("SSH2.out")
resultssh2 = np.zeros(310)
resultssh2[:] = dataweddle

# %% [markdown]
# ##

# %%
t = np.arange(0,3720,12)
my_font = {'fontname':'Cambria', 'size':'13'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1, 0.1, 0.7, 0.7])
ax0.plot(0.0001*ww1)
plt.hlines(0, 0, 3720, colors = "g",linestyles = "dashed")
plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160','180','200','220', '240', '260','280','300','320'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Wind stress curl anomaly(N/m$^3$)',**my_font)

##################################################################################################
ax2 = ax0.twinx() 
ax2.plot(resultweddle,'r')

#my_y_ticks = np.arange(-220, -190, 5)
#plt.ylim(-20, 120)
plt.yticks(**my_font)

plt.ylabel('Sea surface height (cm)',**my_font)

ax0.set_title('Wind stress curl(55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S) and SSH (67$^\circ$S - 63$^\circ$S, 0$^\circ$ - 10$^\circ$E)',**my_font)
#####################################################################################
plt.savefig("windcur652.png")
np.savetxt('sshrelation2.out',resultweddle )

# %%
#t = np.arange(0,3720,12)
my_font = {'fontname':'Cambria', 'size':'13'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1, 0.1, 0.7, 0.7])
#ax0.plot(0.0001*ww1)
ax0.plot(resultssh2)
#plt.hlines(0, 0, 3720, colors = "g",linestyles = "dashed")
#plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160','180','200','220', '240', '260','280','300','320'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Wind stress curl anomaly(N/m$^3$)',**my_font)

##################################################################################################
ax2 = ax0.twinx() 
ax2.plot(resultweddle,'r')

#my_y_ticks = np.arange(-220, -190, 5)
#plt.ylim(-20, 120)
plt.yticks(**my_font)

plt.ylabel('Sea surface height (cm)',**my_font)

ax0.set_title('Wind stress curl(55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S) and SSH (67$^\circ$S - 63$^\circ$S, 0$^\circ$ - 10$^\circ$E)',**my_font)
#####################################################################################
#plt.savefig("windcur652.png")
#np.savetxt('sshrelation2.out',resultweddle )

# %%
dataweddle = np.loadtxt("SSH.out")
resultssh = np.zeros(310)
resultssh[:] = dataweddle

# %%
#t = np.arange(0,3720,12)
my_font = {'fontname':'Cambria', 'size':'13'}
##################################################################
fig = plt.figure(figsize=(20,5), dpi=100)
ax0 = fig.add_axes([0.1, 0.1, 0.7, 0.7])
#ax0.plot(0.0001*ww1)
ax0.plot(resultssh)
#plt.hlines(0, 0, 3720, colors = "g",linestyles = "dashed")
#plt.xticks(range(0,3720,240), ['20', '40', '60', '80','100','120','140','160','180','200','220', '240', '260','280','300','320'],**my_font)
plt.yticks(**my_font)
plt.xlabel('Years',**my_font)
plt.ylabel('Wind stress curl anomaly(N/m$^3$)',**my_font)

##################################################################################################
ax2 = ax0.twinx() 
ax2.plot(resultmaudrise,'r')

#my_y_ticks = np.arange(-220, -190, 5)
#plt.ylim(-20, 120)
plt.yticks(**my_font)

plt.ylabel('Sea surface height (cm)',**my_font)

ax0.set_title('Wind stress curl(55$^\circ$W - 40$^\circ$E, 50$^\circ$S - 70$^\circ$S) and SSH (67$^\circ$S - 63$^\circ$S, 0$^\circ$ - 10$^\circ$E)',**my_font)
#####################################################################################
#plt.savefig("windcur652.png")
#np.savetxt('sshrelation2.out',resultweddle )

# %% [markdown]
# ###
